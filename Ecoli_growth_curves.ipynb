# %%
library(ggplot2)
library(growthcurver)

# %%
ecoli_data <- read.csv("Ecoli_growth.csv", header=T, sep=",")

# %%
unique(subset(ecoli_data, code=="TE" & condition=="aerobic")$date)
# Out:
# [1] "24Nov22" "22Feb23" "3Jul24"  "19Jun24" "23May24" "16May24"

# %% [markdown]
# # Aerobic TE-rich

# %%
ecoli_TE_aerobic <- subset(ecoli_data, code=="TE" & condition=="aerobic")

# %%
model.TE.24Nov22 <- SummarizeGrowth(subset(ecoli_TE_aerobic, date=="24Nov22")$time, subset(ecoli_TE_aerobic, date=="24Nov22")$abs)
TE.24Nov22.predicted <- data.frame(time = subset(ecoli_TE_aerobic, date=="24Nov22")$time, pred.abs = predict(model.TE.24Nov22$model))

# %%
model.TE.22Feb23 <- SummarizeGrowth(subset(ecoli_TE_aerobic, date=="22Feb23")$time, subset(ecoli_TE_aerobic, date=="22Feb23")$abs)
TE.22Feb23.predicted <- data.frame(time = subset(ecoli_TE_aerobic, date=="22Feb23")$time, pred.abs = predict(model.TE.22Feb23$model))

# %%
model.TE.3Jul24 <- SummarizeGrowth(subset(ecoli_TE_aerobic, date=="3Jul24")$time, subset(ecoli_TE_aerobic, date=="3Jul24")$abs)
TE.3Jul24.predicted <- data.frame(time = subset(ecoli_TE_aerobic, date=="3Jul24")$time, pred.abs = predict(model.TE.3Jul24$model))

# %%
model.TE.19Jun24 <- SummarizeGrowth(subset(ecoli_TE_aerobic, date=="19Jun24" & time<="30")$time, subset(ecoli_TE_aerobic, date=="19Jun24" & time<="30")$abs)
TE.19Jun24.predicted <- data.frame(time = subset(ecoli_TE_aerobic, date=="19Jun24" & time<="30")$time, pred.abs = predict(model.TE.19Jun24$model))

# %%
model.TE.23May24 <- SummarizeGrowth(subset(ecoli_TE_aerobic, date=="23May24")$time, subset(ecoli_TE_aerobic, date=="23May24")$abs)
TE.23May24.predicted <- data.frame(time = subset(ecoli_TE_aerobic, date=="23May24")$time, pred.abs = predict(model.TE.23May24$model))

# %%
model.TE.16May24 <- SummarizeGrowth(subset(ecoli_TE_aerobic, date=="16May24")$time, subset(ecoli_TE_aerobic, date=="16May24")$abs)
TE.16May24.predicted <- data.frame(time = subset(ecoli_TE_aerobic, date=="16May24")$time, pred.abs = predict(model.TE.16May24$model))

# %%
ggplot(subset(ecoli_TE_aerobic, date=="24Nov22"), aes(x = time)) + 
   geom_point(data=subset(ecoli_TE_aerobic, date=="24Nov22"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=TE.24Nov22.predicted, aes(y=TE.24Nov22.predicted$pred.abs), color="#b30000", size=1.5) +

   geom_point(data=subset(ecoli_TE_aerobic, date=="22Feb23"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=TE.22Feb23.predicted, aes(y=TE.22Feb23.predicted$pred.abs), color="#b30000", size=1.5) +

xlim(0,30) +
ylim(0,2.2) +

   labs(x = "Time (h)",
       y = "OD600") +
  theme_minimal()
# Out:
# Warning message:
# “Use of `TE.24Nov22.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.22Feb23.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# plot without title

# %%
ecoli_M9_aerobic <- subset(ecoli_data, code=="M9" & condition=="aerobic")

# %%
unique(subset(ecoli_data, code=="M9" & condition=="aerobic")$date)
# Out:
# [1] "24Nov22" "22Feb23"

# %%
model.M9.24Nov22 <- SummarizeGrowth(subset(ecoli_M9_aerobic, date=="24Nov22")$time, subset(ecoli_M9_aerobic, date=="24Nov22")$abs)
M9.24Nov22.predicted <- data.frame(time = subset(ecoli_M9_aerobic, date=="24Nov22")$time, pred.abs = predict(model.M9.24Nov22$model))

model.M9.22Feb23 <- SummarizeGrowth(subset(ecoli_M9_aerobic, date=="22Feb23")$time, subset(ecoli_M9_aerobic, date=="22Feb23")$abs)
M9.22Feb23.predicted <- data.frame(time = subset(ecoli_M9_aerobic, date=="22Feb23")$time, pred.abs = predict(model.M9.22Feb23$model))

# %%
ggplot(subset(ecoli_M9_aerobic, date=="24Nov22"), aes(x = time)) + 
   geom_point(data=subset(ecoli_M9_aerobic, date=="24Nov22"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=M9.24Nov22.predicted, aes(y=M9.24Nov22.predicted$pred.abs), color="#045a8d", size=1.5) +

   geom_point(data=subset(ecoli_M9_aerobic, date=="22Feb23"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=M9.22Feb23.predicted, aes(y=M9.22Feb23.predicted$pred.abs), color="#045a8d", size=1.5) +

xlim(0,30) +
ylim(0,2.2) +

   labs(x = "Time (h)",
       y = "OD600") +
  theme_minimal()
# Out:
# Warning message:
# “Use of `M9.24Nov22.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.22Feb23.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# plot without title

# %%
# Combined plot
ggplot(subset(ecoli_M9_aerobic, date=="24Nov22"), aes(x = time)) + 

# TE-depleted
   geom_point(data=subset(ecoli_M9_aerobic, date=="24Nov22"), aes (y=abs), alpha=0.5, size=3, shape=21, fill="#045a8d", color="black") +
   geom_line(data=M9.24Nov22.predicted, aes(y=M9.24Nov22.predicted$pred.abs), color="#045a8d", size=1.5) +

   geom_point(data=subset(ecoli_M9_aerobic, date=="22Feb23"), aes (y=abs), alpha=0.5, size=3, shape=21, fill="#045a8d", color="black") +
   geom_line(data=M9.22Feb23.predicted, aes(y=M9.22Feb23.predicted$pred.abs), color="#045a8d", size=1.5) +

# TE-rich
   geom_point(data=subset(ecoli_TE_aerobic, date=="24Nov22"), aes (y=abs), alpha=0.5, size=3, shape=21, fill="#b30000", color="black") +
   geom_line(data=TE.24Nov22.predicted, aes(y=TE.24Nov22.predicted$pred.abs), color="#b30000", size=1.5) +

   geom_point(data=subset(ecoli_TE_aerobic, date=="22Feb23"), aes (y=abs), alpha=0.5, size=3, shape=21, fill="#b30000", color="black") +
   geom_line(data=TE.22Feb23.predicted, aes(y=TE.22Feb23.predicted$pred.abs), color="#b30000", size=1.5) +

xlim(0,30) +
ylim(0,2.2) +

   labs(x = "Time (h)",
       y = "OD600") +
  theme_minimal()

ggsave("Ecoli_aerobic_curve.svg", width=12, height=8)
ggsave("Fig-S3_Ecoli_aerobic_curve.png", width=12, height=8)
# Out:
# Warning message:
# “Use of `M9.24Nov22.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.22Feb23.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.24Nov22.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.22Feb23.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.24Nov22.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.22Feb23.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.24Nov22.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.22Feb23.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.24Nov22.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# ...

# %% [markdown]
# # Aerobic CuFe Addition experiment

# %%
# TE-depleted HP-M9 normal anaerobic curve
ecoli_CuFe_aerobic <- subset(ecoli_data, condition=="aerobic"& date=="3Jul24")

# %%
ecoli_CuFe_aerobic
# Out:
#     code          time media condition treatment trace date   abs   O2      no3
# 75  M9HP           0   M9    aerobic   HP        none  3Jul24 0.097 7.19355 NA
# 76  M9HP           0   M9    aerobic   HP        none  3Jul24 0.100 7.19355 NA
# 77  M9HP          12   M9    aerobic   HP        none  3Jul24 0.500 7.19355 NA
# 78  M9HP          12   M9    aerobic   HP        none  3Jul24 0.500 7.19355 NA
# 79  M9HP          15   M9    aerobic   HP        none  3Jul24 0.640 7.19355 NA
# 80  M9HP          15   M9    aerobic   HP        none  3Jul24 0.670 7.19355 NA
# 81  M9HP          18   M9    aerobic   HP        none  3Jul24 0.730 7.19355 NA
# 82  M9HP          18   M9    aerobic   HP        none  3Jul24 0.840 7.19355 NA
# 83  M9HP          21   M9    aerobic   HP        none  3Jul24 0.740 7.19355 NA
# 84  M9HP          21   M9    aerobic   HP        none  3Jul24 0.730 7.19355 NA
# 85  M9HP          24   M9    aerobic   HP        none  3Jul24 0.700 7.19355 NA
# ...

# %%
model.CuFe.cM9.an <- SummarizeGrowth(subset(ecoli_CuFe_aerobic, code=="M9HP")$time, subset(ecoli_CuFe_aerobic, code=="M9HP")$abs)
CuFe.cM9.an.predicted <- data.frame(time = subset(ecoli_CuFe_aerobic, code=="M9HP")$time, pred.abs = predict(model.CuFe.cM9.an$model))

model.CuFe.an <- SummarizeGrowth(subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu")$time, subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu")$abs)
CuFe.an.predicted <- data.frame(time = subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu")$time, pred.abs = predict(model.CuFe.an$model))

model.CuFe12.an <- SummarizeGrowth(subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu_12h")$time, subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu_12h")$abs)
CuFe12.an.predicted <- data.frame(time = subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu_12h")$time, pred.abs = predict(model.CuFe12.an$model))

model.CuFe.TE.an <- SummarizeGrowth(subset(ecoli_CuFe_aerobic, code=="TE")$time, subset(ecoli_CuFe_aerobic, code=="TE")$abs)
CuFe.TE.an.predicted <- data.frame(time = subset(ecoli_CuFe_aerobic, code=="TE")$time, pred.abs = predict(model.CuFe.TE.an$model))

# %%
CuFe.TE.an.predicted
# Out:
#    time pred.abs
# 1   0   0.001261758
# 2   0   0.001261758
# 3  12   1.766036059
# 4  12   1.766036059
# 5  15   1.766975898
# 6  15   1.766975898
# 7  18   1.766999398
# 8  18   1.766999398
# 9  21   1.766999985
# 10 21   1.766999985
# 11 24   1.767000000
# 12 24   1.767000000
# 13 36   1.767000000
# 14 36   1.767000000
# 15 42   1.767000000
# 16 42   1.767000000

# %%
ggplot(ecoli_CuFe_aerobic, aes(x = time)) + 

# HPM9 
   geom_point(data=subset(ecoli_CuFe_aerobic, code=="M9HP"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=CuFe.cM9.an.predicted, aes(y=CuFe.cM9.an.predicted$pred.abs), color="#045a8d", size=2) +

# TE
   geom_point(data=subset(ecoli_CuFe_aerobic, code=="TE"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#b30000", color="black") +
   geom_line(data=CuFe.TE.an.predicted, aes(y=CuFe.TE.an.predicted$pred.abs), color="#b30000", size=2) +

# FeMo added at start
   geom_point(data=subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="gold1", color="black") +
   geom_line(data=CuFe.an.predicted, aes(y=CuFe.an.predicted$pred.abs), color="gold1", size=2) +

# FeMo added at 12 h
   geom_point(data=subset(ecoli_CuFe_aerobic, code=="M9HP_FeCu_12h"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="goldenrod3", color="black") +
   geom_line(data=CuFe12.an.predicted, aes(y=CuFe12.an.predicted$pred.abs), color="goldenrod1", size=2) +

xlim(0,42) +
#ylim(0,1.2) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank()
     ) 

ggsave("Fig-S5_Ecoli_CuFe_aerobic.svg", width=12, height=8)
ggsave("Fig-S5_Ecoli_CuFe_aerobic.png", width=12, height=8)
# Out:
# Warning message:
# “Use of `CuFe.cM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe.TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe12.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe.cM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe.TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe12.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `CuFe.cM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# ...

# %% [markdown]
# # Anaerobic TE-depleted

# %%
# TE-depleted anaerobic curve
ecoli_M9_anaerobic <- subset(ecoli_data, trace=="none" & condition=="anaerobic")

# %%
unique(ecoli_M9_anaerobic$date)
# Out:
# [1] "7Jun23"  "21Feb24" "11Apr24" "25Sep24"

# %%
model.M9.an.7Jun23 <- SummarizeGrowth(subset(ecoli_M9_anaerobic, date=="7Jun23")$time, subset(ecoli_M9_anaerobic, date=="7Jun23")$abs)
M9.7Jun23.an.predicted <- data.frame(time = subset(ecoli_M9_anaerobic, date=="7Jun23")$time, pred.abs = predict(model.M9.an.7Jun23$model))

model.M9.an.11Apr24 <- SummarizeGrowth(subset(ecoli_M9_anaerobic, date=="11Apr24")$time, subset(ecoli_M9_anaerobic, date=="11Apr24")$abs)
M9.11Apr24.an.predicted <- data.frame(time = subset(ecoli_M9_anaerobic, date=="11Apr24")$time, pred.abs = predict(model.M9.an.11Apr24$model))

model.M9.an.21Feb24 <- SummarizeGrowth(subset(ecoli_M9_anaerobic, date=="21Feb24")$time, subset(ecoli_M9_anaerobic, date=="21Feb24")$abs)
M9.21Feb24.an.predicted <- data.frame(time = subset(ecoli_M9_anaerobic, date=="21Feb24")$time, pred.abs = predict(model.M9.an.21Feb24$model))

model.M9.an.25Sep24 <- SummarizeGrowth(subset(ecoli_M9_anaerobic, date=="25Sep24")$time, subset(ecoli_M9_anaerobic, date=="25Sep24")$abs)
M9.25Sep24.an.predicted <- data.frame(time = subset(ecoli_M9_anaerobic, date=="25Sep24")$time, pred.abs = predict(model.M9.an.25Sep24$model))

# %%
# global model for this data
model.M9.an <- SummarizeGrowth(ecoli_M9_anaerobic$time, ecoli_M9_anaerobic$abs)
M9.an.predicted <- data.frame(time = ecoli_M9_anaerobic$time, pred.abs = predict(model.M9.an$model))

# %%
ggplot(ecoli_M9_anaerobic, aes(x = time)) + 

# Global model
   geom_line(data=M9.an.predicted, aes(y=M9.an.predicted$pred.abs), color="#045a8d", size=2) +

# Individual experiment model
   geom_point(data=subset(ecoli_M9_anaerobic, date=="7Jun23"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=M9.7Jun23.an.predicted, aes(y=M9.7Jun23.an.predicted$pred.abs), color="#045a8d", size=0.5) +

   geom_point(data=subset(ecoli_M9_anaerobic, date=="11Apr24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=M9.11Apr24.an.predicted, aes(y=M9.11Apr24.an.predicted$pred.abs), color="#045a8d", size=0.5) +

   geom_point(data=subset(ecoli_M9_anaerobic, date=="21Feb24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=M9.21Feb24.an.predicted, aes(y=M9.21Feb24.an.predicted$pred.abs), color="#045a8d", size=0.5) +

   geom_point(data=subset(ecoli_M9_anaerobic, date=="25Sep24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=M9.25Sep24.an.predicted, aes(y=M9.25Sep24.an.predicted$pred.abs), color="#045a8d", size=0.5) +

xlim(0,25) +
ylim(0,1.2) +

   labs(x = "Time (h)",
       y = "OD600") +
  theme_minimal()

ggsave("Ecoli_M9_anaerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `M9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.7Jun23.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.11Apr24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.21Feb24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `M9.25Sep24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Use of `M9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# ...

# %%
ggplot(ecoli_M9_anaerobic, aes(x = time)) + 

# NO3 data
   geom_point(data=subset(ecoli_M9_anaerobic, date=="7Jun23"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#74a9cf", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="7Jun23"), geom = "line", aes(group = 1, y=no3), color = "#74a9cf") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="11Apr24"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#74a9cf", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="11Apr24"),geom = "line", aes(group = 1, y=no3), color = "#74a9cf") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="21Feb24"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#74a9cf", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="21Feb24"),geom = "line", aes(group = 1, y=no3), color = "#74a9cf") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="25Sep24"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#74a9cf", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="25Sep24"),geom = "line", aes(group = 1, y=no3), color = "#74a9cf") +  # Line plot of average

#Global verage
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic),geom = "line", aes(group = 1, y=no3), color = "#74a9cf", size=2) +  # Line plot of average
  
xlim(0,25) +
ylim(0,150) +

   labs(x = "Time (h)",
       y = "NO3- (ppm)") +
  theme_minimal()

ggsave("Ecoli_M9_anaerobic_curve_no3.svg", width=12, height=8)
# Out:
# Warning message:
# “Removed 27 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 16 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message in max(f):
# “no non-missing arguments to max; returning -Inf”
# Warning message:
# “Computation failed in `stat_summary()`.
# Caused by error in `seq_len()`:
# ! argument must be coercible to non-negative integer”
# Warning message:
# “Removed 43 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 27 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 16 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 27 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 16 rows containing non-finite outside the scale range
# ...

# %%
ggplot(ecoli_M9_anaerobic, aes(x = time)) + 

# O2ta
   geom_point(data=subset(ecoli_M9_anaerobic, date=="7Jun23"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#2b8cbe", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="7Jun23"), geom = "line", aes(group = 1, y=O2), color = "#2b8cbe") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="11Apr24"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#2b8cbe", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="11Apr24"),geom = "line", aes(group = 1, y=O2), color = "#2b8cbe") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="21Feb24"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#2b8cbe", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="21Feb24"),geom = "line", aes(group = 1, y=O2), color = "#2b8cbe") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="25Sep24"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#2b8cbe", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="25Sep24"),geom = "line", aes(group = 1, y=O2), color = "#2b8cbe") +  # Line plot of average

#Global verage
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic),geom = "line", aes(group = 1, y=O2), color = "#2b8cbe", size=2) +  # Line plot of average
  
xlim(0,25) +
ylim(0,7) +

   labs(x = "Time (h)",
       y = "O2") +
  theme_minimal()

ggsave("Ecoli_M9_anaerobic_curve_o2.svg", width=12, height=8)
# Out:
# Warning message:
# “Removed 41 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 8 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 8 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 4 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 61 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 41 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 4 rows containing missing values or values outside the scale range
# ...

# %%
ggplot(ecoli_M9_anaerobic, aes(x = time)) + 

# Ph data
   geom_point(data=subset(ecoli_M9_anaerobic, date=="7Jun23"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#bdc9e1", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="7Jun23"), geom = "line", aes(group = 1, y=ph), color = "#bdc9e1") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="11Apr24"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#bdc9e1", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="11Apr24"),geom = "line", aes(group = 1, y=ph), color = "#bdc9e1") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="21Feb24"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#bdc9e1", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="21Feb24"),geom = "line", aes(group = 1, y=ph), color = "#bdc9e1") +  # Line plot of average

   geom_point(data=subset(ecoli_M9_anaerobic, date=="25Sep24"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#bdc9e1", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic, date=="25Sep24"),geom = "line", aes(group = 1, y=ph), color = "#bdc9e1") +  # Line plot of average

#Global verage
   stat_summary(fun = mean, data=subset(ecoli_M9_anaerobic),geom = "line", aes(group = 1, y=ph), color = "#bdc9e1", size=2) +  # Line plot of average
  
xlim(0,25) +
ylim(4,8) +

   labs(x = "Time (h)",
       y = "pH") +
  theme_minimal()

ggsave("Ecoli_M9_anaerobic_curve_ph.svg", width=12, height=8)
# Out:
# Warning message:
# “Removed 41 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 16 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message in max(f):
# “no non-missing arguments to max; returning -Inf”
# Warning message:
# “Computation failed in `stat_summary()`.
# Caused by error in `seq_len()`:
# ! argument must be coercible to non-negative integer”
# Warning message:
# “Removed 26 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message in max(f):
# “no non-missing arguments to max; returning -Inf”
# Warning message:
# “Computation failed in `stat_summary()`.
# Caused by error in `seq_len()`:
# ! argument must be coercible to non-negative integer”
# Warning message:
# “Removed 83 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 41 rows containing missing values or values outside the scale range
# ...

# %% [markdown]
# # Anaerobic TE-rich

# %%
# TE-rich anaerobic curve
ecoli_TE_anaerobic <- subset(ecoli_data, code=="TE" & condition=="anaerobic")

# %%
unique(subset(ecoli_data, code=="TE" & condition=="anaerobic")$date)
# Out:
# [1] "7Jun23"  "11Apr24" "17Jul24" "25Sep24"

# %%
model.TE.an.7Jun23 <- SummarizeGrowth(subset(ecoli_TE_anaerobic, date=="7Jun23")$time, subset(ecoli_TE_anaerobic, date=="7Jun23")$abs)
TE.7Jun23.an.predicted <- data.frame(time = subset(ecoli_TE_anaerobic, date=="7Jun23")$time, pred.abs = predict(model.TE.an.7Jun23$model))

model.TE.an.11Apr24 <- SummarizeGrowth(subset(ecoli_TE_anaerobic, date=="11Apr24")$time, subset(ecoli_TE_anaerobic, date=="11Apr24")$abs)
TE.11Apr24.an.predicted <- data.frame(time = subset(ecoli_TE_anaerobic, date=="11Apr24")$time, pred.abs = predict(model.TE.an.11Apr24$model))

model.TE.an.17Jul24 <- SummarizeGrowth(subset(ecoli_TE_anaerobic, date=="17Jul24")$time, subset(ecoli_TE_anaerobic, date=="17Jul24")$abs)
TE.17Jul24.an.predicted <- data.frame(time = subset(ecoli_TE_anaerobic, date=="17Jul24")$time, pred.abs = predict(model.TE.an.17Jul24$model))

model.TE.an.25Sep24 <- SummarizeGrowth(subset(ecoli_TE_anaerobic, date=="25Sep24")$time, subset(ecoli_TE_anaerobic, date=="25Sep24")$abs)
TE.25Sep24.an.predicted <- data.frame(time = subset(ecoli_TE_anaerobic, date=="25Sep24")$time, pred.abs = predict(model.TE.an.25Sep24$model))

# %%
# global model for this data
model.TE.an <- SummarizeGrowth(ecoli_TE_anaerobic$time, ecoli_TE_anaerobic$abs)
TE.an.predicted <- data.frame(time = ecoli_TE_anaerobic$time, pred.abs = predict(model.TE.an$model))

# %%
ggplot(ecoli_TE_anaerobic, aes(x = time)) + 

# Global model
   geom_line(data=TE.an.predicted, aes(y=TE.an.predicted$pred.abs), color="#b30000", size=2) +

# Individual experiment model
   geom_point(data=subset(ecoli_TE_anaerobic, date=="7Jun23"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=TE.7Jun23.an.predicted, aes(y=TE.7Jun23.an.predicted$pred.abs), color="#b30000", size=0.5) +

   geom_point(data=subset(ecoli_TE_anaerobic, date=="11Apr24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=TE.11Apr24.an.predicted, aes(y=TE.11Apr24.an.predicted$pred.abs), color="#b30000", size=0.5) +

   geom_point(data=subset(ecoli_TE_anaerobic, date=="17Jul24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=TE.17Jul24.an.predicted, aes(y=TE.17Jul24.an.predicted$pred.abs), color="#b30000", size=0.5) +

   geom_point(data=subset(ecoli_TE_anaerobic, date=="25Sep24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="darkgray", color="black") +
   geom_line(data=TE.25Sep24.an.predicted, aes(y=TE.25Sep24.an.predicted$pred.abs), color="#b30000", size=0.5) +

xlim(0,25) +
ylim(0,1.2) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
     ) 

ggsave("Ecoli_TE_anaerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.7Jun23.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.11Apr24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.17Jul24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `TE.25Sep24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 13 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Use of `TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# ...

# %%
ggplot(ecoli_TE_anaerobic, aes(x = time)) + 

# NO3 data
   geom_point(data=subset(ecoli_TE_anaerobic, date=="7Jun23"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#fc8d59", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="7Jun23"), geom = "line", aes(group = 1, y=no3), color = "#fc8d59") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="11Apr24"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#fc8d59", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="11Apr24"),geom = "line", aes(group = 1, y=no3), color = "#fc8d59") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="17Jul24"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#fc8d59", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="17Jul24"),geom = "line", aes(group = 1, y=no3), color = "#fc8d59") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="25Sep24"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#fc8d59", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="25Sep24"),geom = "line", aes(group = 1, y=no3), color = "#fc8d59") +  # Line plot of average

#Global verage
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic),geom = "line", aes(group = 1, y=no3), color = "#fc8d59", size=2) +  # Line plot of average
  
xlim(0,25) +
ylim(0,150) +

   labs(x = "Time (h)",
       y = "NO3- (ppm)") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
     ) 

ggsave("Ecoli_TE_anaerobic_curve_no3.svg", width=12, height=8)
# Out:
# Warning message:
# “Removed 14 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 40 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message in max(f):
# “no non-missing arguments to max; returning -Inf”
# Warning message:
# “Computation failed in `stat_summary()`.
# Caused by error in `seq_len()`:
# ! argument must be coercible to non-negative integer”
# Warning message:
# “Removed 54 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 14 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 40 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 14 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 40 rows containing non-finite outside the scale range
# ...

# %%
ggplot(ecoli_TE_anaerobic, aes(x = time)) + 

# O2 data
   geom_point(data=subset(ecoli_TE_anaerobic, date=="7Jun23"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#e34a33", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="7Jun23"), geom = "line", aes(group = 1, y=O2), color = "#e34a33") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="11Apr24"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#e34a33", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="11Apr24"),geom = "line", aes(group = 1, y=O2), color = "#e34a33") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="17Jul24"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#e34a33", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="17Jul24"),geom = "line", aes(group = 1, y=O2), color = "#e34a33") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="25Sep24"), aes(y=O2), alpha=0.5, size=4, shape=21, fill="#e34a33", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="25Sep24"),geom = "line", aes(group = 1, y=O2), color = "#e34a33") +  # Line plot of average

#Global verage
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic),geom = "line", aes(group = 1, y=O2), color = "#e34a33", size=2) +  # Line plot of average
  
xlim(0,25) +
ylim(0,7) +

   labs(x = "Time (h)",
       y = "O2 (%)") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
     ) 

ggsave("Ecoli_TE_anaerobic_curve_o2.svg", width=12, height=8)
# Out:
# Warning message:
# “Removed 42 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 8 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 17 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 69 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 42 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 17 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# ...

# %%
ggplot(ecoli_TE_anaerobic, aes(x = time)) + 

# pH data
   geom_point(data=subset(ecoli_TE_anaerobic, date=="7Jun23"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#fdcc8a", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="7Jun23"), geom = "line", aes(group = 1, y=ph), color = "#fdcc8a") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="11Apr24"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#fdcc8a", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="11Apr24"),geom = "line", aes(group = 1, y=ph), color = "#fdcc8a") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="17Jul24"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#fdcc8a", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="17Jul24"),geom = "line", aes(group = 1, y=ph), color = "#fdcc8a") +  # Line plot of average

   geom_point(data=subset(ecoli_TE_anaerobic, date=="25Sep24"), aes(y=ph), alpha=0.5, size=4, shape=21, fill="#fdcc8a", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_TE_anaerobic, date=="25Sep24"),geom = "line", aes(group = 1, y=ph), color = "#fdcc8a") +  # Line plot of average

#Global verage
   stat_smooth(fun = mean, data=subset(ecoli_TE_anaerobic),geom = "line", aes(group = 1, y=ph), color = "#fdcc8a", size=2) +  # Line plot of average
  
xlim(0,25) +
ylim(4,8) +

   labs(x = "Time (h)",
       y = "pH") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
     ) 

ggsave("Ecoli_TE_anaerobic_curve_ph.svg", width=12, height=8)
# Out:
# Warning message in stat_smooth(fun = mean, data = subset(ecoli_TE_anaerobic), geom = "line", :
# “Ignoring unknown parameters: `fun`”
# Warning message:
# “Removed 42 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message:
# “Removed 40 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message in max(f):
# “no non-missing arguments to max; returning -Inf”
# Warning message:
# “Computation failed in `stat_summary()`.
# Caused by error in `seq_len()`:
# ! argument must be coercible to non-negative integer”
# Warning message:
# “Removed 18 rows containing non-finite outside the scale range
# (`stat_summary()`).”
# Warning message in max(f):
# “no non-missing arguments to max; returning -Inf”
# Warning message:
# “Computation failed in `stat_summary()`.
# Caused by error in `seq_len()`:
# ! argument must be coercible to non-negative integer”
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# ...

# %%
save.image()

# %% [markdown]
# # Making the 3 plot for the different TE-Depleted conditions

# %% [markdown]
# ### Normal M9 with standard reagents

# %%
# TE-depleted M9 normal anaerobic curve
ecoli_nM9_anaerobic <- subset(ecoli_data, code=="M9" & condition=="anaerobic")

# %%
unique(ecoli_nM9_anaerobic$date)
# Out:
# [1] "7Jun23"

# %%
model.nM9.an <- SummarizeGrowth(ecoli_nM9_anaerobic$time, ecoli_nM9_anaerobic$abs)
nM9.an.predicted <- data.frame(time = ecoli_nM9_anaerobic$time, pred.abs = predict(model.nM9.an$model))

# %%
ggplot(ecoli_nM9_anaerobic, aes(x = time)) + 

   geom_point(data=ecoli_nM9_anaerobic, aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=nM9.an.predicted, aes(y=nM9.an.predicted$pred.abs), color="#045a8d", size=2) +

xlim(0,25) +
ylim(0,1.2) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
     ) 

ggsave("Ecoli_nM9_anaerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `nM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Use of `nM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# plot without title

# %% [markdown]
# ### High Purity M9

# %%
# TE-depleted HP-M9 normal anaerobic curve
ecoli_HPM9_anaerobic <- subset(ecoli_data, code=="M9HP" & condition=="anaerobic")

# %%
unique(ecoli_HPM9_anaerobic$date)
# Out:
# [1] "21Feb24" "25Sep24"

# %%
model.HPM9.an.21Feb24 <- SummarizeGrowth(subset(ecoli_HPM9_anaerobic, date=="21Feb24")$time, subset(ecoli_HPM9_anaerobic, date=="21Feb24")$abs)
HPM9.21Feb24.an.predicted <- data.frame(time = subset(ecoli_HPM9_anaerobic, date=="21Feb24")$time, pred.abs = predict(model.HPM9.an.21Feb24$model))

model.HPM9.an.25Sep24 <- SummarizeGrowth(subset(ecoli_HPM9_anaerobic, date=="25Sep24")$time, subset(ecoli_HPM9_anaerobic, date=="25Sep24")$abs)
HPM9.25Sep24.an.predicted <- data.frame(time = subset(ecoli_HPM9_anaerobic, date=="25Sep24")$time, pred.abs = predict(model.HPM9.an.25Sep24$model))

# Global model
model.HPM9.an <- SummarizeGrowth(ecoli_HPM9_anaerobic$time, ecoli_HPM9_anaerobic$abs)
HPM9.an.predicted <- data.frame(time = ecoli_HPM9_anaerobic$time, pred.abs = predict(model.HPM9.an$model))

# %%
ggplot(ecoli_HPM9_anaerobic, aes(x = time)) + 

# Global model
   geom_line(data=HPM9.an.predicted, aes(y=HPM9.an.predicted$pred.abs), color="#045a8d", size=2) +

# Individual experiment model
   geom_point(data=subset(ecoli_HPM9_anaerobic, date=="21Feb24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=HPM9.21Feb24.an.predicted, aes(y=HPM9.21Feb24.an.predicted$pred.abs), color="#045a8d", size=0.5) +

   geom_point(data=subset(ecoli_HPM9_anaerobic, date=="25Sep24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=HPM9.25Sep24.an.predicted, aes(y=HPM9.25Sep24.an.predicted$pred.abs), color="#045a8d", size=0.5) +

xlim(0,25) +
ylim(0,1.2) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank()
     ) 

ggsave("Ecoli_HPM9_anaerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `HPM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `HPM9.21Feb24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `HPM9.25Sep24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `HPM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `HPM9.21Feb24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `HPM9.25Sep24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# plot without title

# %% [markdown]
# ### Chelex-M9

# %%
# TE-depleted HP-M9 normal anaerobic curve
ecoli_PCM9_anaerobic <- subset(ecoli_data, code=="M9PC" & condition=="anaerobic")

# %%
unique(ecoli_PCM9_anaerobic$date)
# Out:
# [1] "21Feb24" "11Apr24"

# %%
model.PCM9.an.21Feb24 <- SummarizeGrowth(subset(ecoli_PCM9_anaerobic, date=="21Feb24")$time, subset(ecoli_PCM9_anaerobic, date=="21Feb24")$abs)
PCM9.21Feb24.an.predicted <- data.frame(time = subset(ecoli_PCM9_anaerobic, date=="21Feb24")$time, pred.abs = predict(model.PCM9.an.21Feb24$model))

model.PCM9.an.11Apr24 <- SummarizeGrowth(subset(ecoli_PCM9_anaerobic, date=="11Apr24")$time, subset(ecoli_PCM9_anaerobic, date=="11Apr24")$abs)
PCM9.11Apr24.an.predicted <- data.frame(time = subset(ecoli_PCM9_anaerobic, date=="11Apr24")$time, pred.abs = predict(model.PCM9.an.11Apr24$model))

# Global model
model.PCM9.an <- SummarizeGrowth(ecoli_PCM9_anaerobic$time, ecoli_PCM9_anaerobic$abs)
PCM9.an.predicted <- data.frame(time = ecoli_PCM9_anaerobic$time, pred.abs = predict(model.PCM9.an$model))

# %%
ggplot(ecoli_PCM9_anaerobic, aes(x = time)) + 

# Global model
   geom_line(data=PCM9.an.predicted, aes(y=PCM9.an.predicted$pred.abs), color="#045a8d", size=2) +

# Individual experiment model
   geom_point(data=subset(ecoli_PCM9_anaerobic, date=="21Feb24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=PCM9.21Feb24.an.predicted, aes(y=PCM9.21Feb24.an.predicted$pred.abs), color="#045a8d", size=0.5) +

   geom_point(data=subset(ecoli_PCM9_anaerobic, date=="11Apr24"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=PCM9.11Apr24.an.predicted, aes(y=PCM9.11Apr24.an.predicted$pred.abs), color="#045a8d", size=0.5) +

xlim(0,25) +
ylim(0,1.2) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank()
     ) 

ggsave("Ecoli_PCM9_anaerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `PCM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `PCM9.21Feb24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `PCM9.11Apr24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `PCM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `PCM9.21Feb24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `PCM9.11Apr24.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# plot without title

# %% [markdown]
# # FeMo addition experiment

# %%
# TE-depleted HP-M9 normal anaerobic curve
ecoli_FeMo_anaerobic <- subset(ecoli_data, condition=="anaerobic"& date=="25Sep24")

# %%
model.FeMo.cM9.an <- SummarizeGrowth(subset(ecoli_FeMo_anaerobic, code=="M9HP")$time, subset(ecoli_FeMo_anaerobic, code=="M9HP")$abs)
FeMo.cM9.an.predicted <- data.frame(time = subset(ecoli_FeMo_anaerobic, code=="M9HP")$time, pred.abs = predict(model.FeMo.cM9.an$model))

model.FeMo.an <- SummarizeGrowth(subset(ecoli_FeMo_anaerobic, code=="HP_FeMo")$time, subset(ecoli_FeMo_anaerobic, code=="HP_FeMo")$abs)
FeMo.an.predicted <- data.frame(time = subset(ecoli_FeMo_anaerobic, code=="HP_FeMo")$time, pred.abs = predict(model.FeMo.an$model))

model.FeMo12.an <- SummarizeGrowth(subset(ecoli_FeMo_cM9_anaerobic, code=="HP_FeMo_12h")$time, subset(ecoli_FeMo_cM9_anaerobic, code=="HP_FeMo_12h")$abs)
FeMo12.an.predicted <- data.frame(time = subset(ecoli_FeMo_cM9_anaerobic, code=="HP_FeMo_12h")$time, pred.abs = predict(model.FeMo12.an$model))

model.FeMo.TE.an <- SummarizeGrowth(subset(ecoli_FeMo_cM9_anaerobic, code=="TE")$time, subset(ecoli_FeMo_cM9_anaerobic, code=="TE")$abs)
FeMo.TE.an.predicted <- data.frame(time = subset(ecoli_FeMo_cM9_anaerobic, code=="TE")$time, pred.abs = predict(model.FeMo.TE.an$model))

# %%
ggplot(ecoli_FeMo_anaerobic, aes(x = time)) + 

# HPM9 
   geom_point(data=subset(ecoli_FeMo_anaerobic, code=="M9HP"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=FeMo.cM9.an.predicted, aes(y=FeMo.cM9.an.predicted$pred.abs), color="#045a8d", size=2) +

# TE
   geom_point(data=subset(ecoli_FeMo_anaerobic, code=="TE"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#b30000", color="black") +
   geom_line(data=FeMo.TE.an.predicted, aes(y=FeMo.TE.an.predicted$pred.abs), color="#b30000", size=2) +

# FeMo added at start
   geom_point(data=subset(ecoli_FeMo_anaerobic, code=="HP_FeMo"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="gold1", color="black") +
   geom_line(data=FeMo.an.predicted, aes(y=FeMo.an.predicted$pred.abs), color="gold1", size=2) +

# FeMo added at 12 h
   geom_point(data=subset(ecoli_FeMo_cM9_anaerobic, code=="HP_FeMo_12h"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="goldenrod3", color="black") +
   geom_line(data=FeMo12.an.predicted, aes(y=FeMo12.an.predicted$pred.abs), color="goldenrod1", size=2) +

xlim(0,25) +
ylim(0,1.2) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank()
     ) 

ggsave("Ecoli_FeMo_anaerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `FeMo.cM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `FeMo.TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `FeMo.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `FeMo12.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `FeMo.cM9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `FeMo.TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `FeMo.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `FeMo12.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# plot without title

# %%
ggplot(ecoli_FeMo_anaerobic, aes(x = time)) + 

# NO3 data
   geom_point(data=subset(ecoli_FeMo_anaerobic, code=="M9HP"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_FeMo_anaerobic, code=="M9HP"), geom = "line", aes(group = 1, y=no3), color = "#045a8d", linetype = "dotdash", size=1) +  # Line plot of average

   geom_point(data=subset(ecoli_FeMo_anaerobic, code=="TE"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="#b30000", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_FeMo_anaerobic, code=="TE"),geom = "line", aes(group = 1, y=no3), color = "#b30000", linetype = "dotdash", size=1) +  # Line plot of average

   geom_point(data=subset(ecoli_FeMo_anaerobic, code=="HP_FeMo"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="gold1", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_FeMo_anaerobic, code=="HP_FeMo"),geom = "line", aes(group = 1, y=no3), color = "gold1", linetype = "dotdash", size=1) +  # Line plot of average

   geom_point(data=subset(ecoli_FeMo_anaerobic, code=="HP_FeMo_12h"), aes(y=no3), alpha=0.5, size=4, shape=21, fill="goldenrod3", color="black") +
   stat_summary(fun = mean, data=subset(ecoli_FeMo_anaerobic, code=="HP_FeMo_12h"),geom = "line", aes(group = 1, y=no3), color = "goldenrod3", linetype = "dotdash", size=1) +  # Line plot of average
  
xlim(0,25) +
ylim(0,150) +

   labs(x = "Time (h)",
       y = "NO3- (ppm)") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
     ) 

ggsave("Ecoli_FeMo_anaerobic_curve_no3.svg", width=12, height=8)
# Out:
# Warning message:
# “Removed 1 row containing non-finite outside the scale range (`stat_summary()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 1 row containing non-finite outside the scale range (`stat_summary()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
save.image()

# %% [markdown]
# # Bacillus subtilis growth

# %%
bsubtilis_data <- read.csv("Bsubtilis_growth.csv", header=T, sep=",")

# %%
model.bsub.M9 <- SummarizeGrowth(subset(bsubtilis_data, code=="M9")$time, subset(bsubtilis_data, code=="M9")$abs)
bsub.M9.predicted <- data.frame(time = subset(bsubtilis_data, code=="M9")$time, pred.abs = predict(model.bsub.M9$model))

model.bsub.TE <- SummarizeGrowth(subset(bsubtilis_data, code=="TE")$time, subset(bsubtilis_data, code=="TE")$abs)
bsub.TE.predicted <- data.frame(time = subset(bsubtilis_data, code=="TE")$time, pred.abs =predict(model.bsub.TE$model))

# %%
ggplot(bsubtilis_data, aes(x = time)) + 

# M9 
   geom_point(data=subset(bsubtilis_data, code=="M9"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=bsub.M9.predicted, aes(y=bsub.M9.predicted$pred.abs), color="#045a8d", size=2) +

# TE
   geom_point(data=subset(bsubtilis_data, code=="TE"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#b30000", color="black") +
   geom_line(data=bsub.TE.predicted, aes(y=bsub.TE.predicted$pred.abs), color="#b30000", size=2) +

xlim(0,30) +
ylim(0,6) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank()
     ) 

ggsave("Bsubtili_aerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `bsub.M9.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `bsub.TE.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `bsub.M9.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `bsub.TE.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `bsub.M9.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `bsub.TE.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# plot without title

# %%
model.bsub.M9.an <- SummarizeGrowth(subset(bsubtilis_data, code=="M9" & condition=="anaerobic")$time, subset(bsubtilis_data, code=="M9" & condition=="anaerobic")$abs)
bsub.M9.an.predicted <- data.frame(time = subset(bsubtilis_data, code=="M9" & condition=="anaerobic")$time, pred.abs = predict(model.bsub.M9.an$model))

model.bsub.TE.an <- SummarizeGrowth(subset(bsubtilis_data, code=="TE" & condition=="anaerobic")$time, subset(bsubtilis_data, code=="TE" & condition=="anaerobic")$abs)
bsub.TE.an.predicted <- data.frame(time = subset(bsubtilis_data, code=="TE" & condition=="anaerobic")$time, pred.abs =predict(model.bsub.TE.an$model))

# %%
ggplot(subset(bsubtilis_data, code=="M9" & condition=="anaerobic"), aes(x = time)) + 

# M9 
   geom_point(data=subset(bsubtilis_data, code=="M9" & condition=="anaerobic"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=bsub.M9.an.predicted, aes(y=bsub.M9.an.predicted$pred.abs), color="#045a8d", size=2) +

# TE
   geom_point(data=subset(bsubtilis_data, code=="TE" & condition=="anaerobic"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#b30000", color="black") +
   geom_line(data=bsub.TE.an.predicted, aes(y=bsub.TE.an.predicted$pred.abs), color="#b30000", size=2) +

xlim(0,30) +
ylim(0,2) +

   labs(x = "Time (h)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank()
     ) 

ggsave("Bsubtili_anaerobic_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `bsub.M9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `bsub.TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Use of `bsub.M9.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `bsub.TE.an.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# # S bacillaris growth

# %%
sbacillaris_data <- read.csv("Sbacillaris_growth.csv", header=T, sep=",")

# %%
model.sbac.TE <- SummarizeGrowth(subset(sbacillaris_data, code=="BBM_TE")$time, subset(sbacillaris_data, code=="BBM_TE")$abs)
sbac.TE.predicted <- data.frame(time = subset(sbacillaris_data, code=="BBM_TE")$time, pred.abs =predict(model.sbac.TE$model))

model.sbac.BBM1 <- SummarizeGrowth(subset(sbacillaris_data, code=="BBM_1")$time, subset(sbacillaris_data, code=="BBM_1")$abs)
sbac.BBM1.predicted <- data.frame(time = subset(sbacillaris_data, code=="BBM_1")$time, pred.abs =predict(model.sbac.BBM1$model))

model.sbac.BBM2 <- SummarizeGrowth(subset(sbacillaris_data, code=="BBM_2")$time, subset(sbacillaris_data, code=="BBM_2")$abs)
sbac.BBM2.predicted <- data.frame(time = subset(sbacillaris_data, code=="BBM_2")$time, pred.abs =predict(model.sbac.BBM2$model))

model.sbac.BBM3 <- SummarizeGrowth(subset(sbacillaris_data, code=="BBM_3")$time, subset(sbacillaris_data, code=="BBM_3")$abs)
sbac.BBM3.predicted <- data.frame(time = subset(sbacillaris_data, code=="BBM_3")$time, pred.abs =predict(model.sbac.BBM3$model))

model.sbac.BBM4 <- SummarizeGrowth(subset(sbacillaris_data, code=="BBM_4")$time, subset(sbacillaris_data, code=="BBM_4")$abs)
sbac.BBM4.predicted <- data.frame(time = subset(sbacillaris_data, code=="BBM_4")$time, pred.abs =predict(model.sbac.BBM4$model))

# %%
ggplot(sbacillaris_data, aes(x = time)) + 

# BBM TE
   geom_point(data=subset(sbacillaris_data, code=="BBM_TE"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#b30000", color="black") +
   geom_line(data=sbac.TE.predicted, aes(y=sbac.TE.predicted$pred.abs), color="#b30000", size=2) +

# BBM1 
#   geom_point(data=subset(sbacillaris_data, code=="BBM_1"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
#   geom_line(data=sbac.BBM1.predicted, aes(y=sbac.BBM1.predicted$pred.abs), color="#045a8d", size=2) +

# BBM2 
#   geom_point(data=subset(sbacillaris_data, code=="BBM_2"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
#   geom_line(data=sbac.BBM2.predicted, aes(y=sbac.BBM2.predicted$pred.abs), color="#045a8d", size=2) +

# BBM3 
#   geom_point(data=subset(sbacillaris_data, code=="BBM_3"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
#   geom_line(data=sbac.BBM3.predicted, aes(y=sbac.BBM3.predicted$pred.abs), color="#045a8d", size=2) +

# BBM4 
   geom_point(data=subset(sbacillaris_data, code=="BBM_3"), aes (y=abs), alpha=0.5, size=4, shape=21, fill="#045a8d", color="black") +
   geom_line(data=sbac.BBM3.predicted, aes(y=sbac.BBM3.predicted$pred.abs), color="#045a8d", size=2) +


xlim(0,15) +
ylim(0,1.5) +

   labs(x = "Time (days)",
       y = "OD600") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank()
     ) 

ggsave("Sbacillaris_curve_abs.svg", width=12, height=8)
# Out:
# Warning message:
# “Use of `sbac.TE.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `sbac.BBM3.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `sbac.TE.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# Warning message:
# “Use of `sbac.BBM3.predicted$pred.abs` is discouraged.
# ℹ Use `pred.abs` instead.”
# plot without title

# %% [markdown]
# ## S. bacillaris rETR data

# %%
sbacillaris_retr <- read.csv("Sbacillaris_rETR.csv", header=T, sep=",")

# %%
sbacillaris_retr
# Out:
#    code   time PAR     Fo  Fm  rETR
# 1  BBM_TE 14     36.56  89 301  25.74990
# 2  BBM_TE 14     94.22  97 297  63.44781
# 3  BBM_TE 14    200.50  93 295 137.29153
# 4  BBM_TE 14    314.30  88 295 220.54271
# 5  BBM_TE 14    443.50  96 297 300.14646
# 6  BBM_TE 14    601.00  91 294 414.97619
# 7  BBM_TE 14    782.00  85 292 554.36301
# 8  BBM_TE 14    986.00  93 288 667.60417
# 9  BBM_TE 14   1213.00 102 285 778.87368
# 10 BBM_TE 14     36.56 101 379  26.81710
# 11 BBM_TE 14     94.22 119 380  64.71426
# 12 BBM_TE 14    200.50 115 378 139.50132
# 13 BBM_TE 14    314.30 117 370 214.91324
# 14 BBM_TE 14    443.50 102 374 322.54545
# 15 BBM_TE 14    601.00 125 365 395.17808
# 16 BBM_TE 14    782.00 116 366 534.15301
# 17 BBM_TE 14    986.00 119 366 665.41530
# 18 BBM_TE 14   1213.00 120 363 812.00826
# 19 BBM_1  14     36.56 123 390  25.02954
# 20 BBM_1  14     94.22 126 389  63.70144
# 21 BBM_1  14    200.50 110 389 143.80334
# 22 BBM_1  14    314.30 122 382 213.92147
# ...

# %% [markdown]
# # Glucose plots

# %%
ecoli_glu_anerobic <- subset(ecoli_data, date=="11Apr24" & (time==6 | time==12 | time==24))

# %%
ecoli_glu_anerobic
# Out:
#     code time media condition treatment trace date    abs   O2
# 442 TE    6   M9    anaerobic none      TE    11Apr24 0.330 0.2671890
# 443 TE    6   M9    anaerobic none      TE    11Apr24 0.330 0.3425500
# 444 TE    6   M9    anaerobic none      TE    11Apr24 0.330        NA
# 448 TE   12   M9    anaerobic none      TE    11Apr24 1.180 0.0513825
# 449 TE   12   M9    anaerobic none      TE    11Apr24 1.140 0.0513825
# 450 TE   12   M9    anaerobic none      TE    11Apr24 1.130        NA
# 451 TE   24   M9    anaerobic none      TE    11Apr24 1.050 0.0513825
# 452 TE   24   M9    anaerobic none      TE    11Apr24 1.200 0.0513825
# 453 TE   24   M9    anaerobic none      TE    11Apr24 1.080        NA
# 460 M9PC  6   M9    anaerobic chelex    none  11Apr24 0.166 3.6652850
# 461 M9PC  6   M9    anaerobic chelex    none  11Apr24 0.190 3.0486950
# 462 M9PC  6   M9    anaerobic chelex    none  11Apr24 0.166        NA
# ...

# %%
ggplot(ecoli_glu_anerobic, aes(x=as.factor(time), y=abs, fill=code)) +
       geom_boxplot() + 

       scale_fill_manual(values=c('#045a8d','#b30000')) +

   labs(x = "Time (hours)",
       y = "OD (600 nm)") +

  theme_minimal(base_size = 12) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
      legend.position="none"
     ) 

ggsave("Ecoli_anaerobic_bar_abs.svg", width=4, height=2)
# Out:
# plot without title

# %%
ggplot(ecoli_glu_anerobic, aes(x=as.factor(time), y=O2, fill=code)) +
       geom_boxplot() + 

       scale_fill_manual(values=c('#045a8d','#b30000')) +

   labs(x = "Time (hours)",
       y = "O2") +

  theme_minimal(base_size = 12) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
      legend.position="none"
     ) 

ggsave("Ecoli_anaerobic_bar_o2.svg", width=4, height=2)
# Out:
# Warning message:
# “Removed 6 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# Warning message:
# “Removed 6 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
ggplot(ecoli_glu_anerobic, aes(x=as.factor(time), y=no3, fill=code)) +
       geom_boxplot() + 

       scale_fill_manual(values=c('#045a8d','#b30000')) +

   labs(x = "Time (hours)",
       y = "NO3") +

  theme_minimal(base_size = 12) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
            legend.position="none"
     ) 

ggsave("Ecoli_anaerobic_bar_no3.svg", width=4, height=2)
# Out:
# plot without title

# %%
ggplot(ecoli_glu_anerobic, aes(x=as.factor(time), y=ph, fill=code)) +
       geom_boxplot() + 

       scale_fill_manual(values=c('#045a8d','#b30000')) +

   labs(x = "Time (hours)",
       y = "pH") +

ylim(6,8) +

  theme_minimal(base_size = 12) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
            legend.position="none"
     ) 

ggsave("Ecoli_anaerobic_bar_ph.svg", width=4, height=2)
# Out:
# plot without title

# %%
ggplot(ecoli_glu_anerobic, aes(x=as.factor(time), y=glu, fill=code)) +
       geom_boxplot() + 

       scale_fill_manual(values=c('#045a8d','#b30000')) +

   labs(x = "Time (hours)",
       y = "glu") +

  theme_minimal(base_size = 12) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
            legend.position="none"
     ) 

ggsave("Ecoli_anaerobic_bar_glu.svg", width=4, height=2)
# Out:
# plot without title

# %% [markdown]
# # Siderophores

# %%
ecoli_sidero <- read.csv("Ecoli_Siderophores.csv", header=T, sep=",")

# %%
names(ecoli_sidero)
# Out:
# [1] "code"      "time"      "media"     "condition" "treatment" "trace"
# [7] "date"      "psu"

# %%
ggplot(subset(ecoli_sidero, code=="M9_HP" | code=="TE"), aes(x=as.factor(time), y=psu, fill=code)) +
       geom_boxplot() + 
geom_hline(yintercept = 0) +

       scale_fill_manual(values=c('#045a8d','#b30000')) +

   labs(x = "Time (hours)",
       y = "psu (% of EDTA)") +

  theme_minimal(base_size = 16) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
            legend.position="none"
     ) 

ggsave("Fig-S8_Ecoli_siderophores.svg", width=12, height=8)
ggsave("Fig-S8_Ecoli_siderophores.png", width=12, height=8)
# Out:
# plot without title

# %% [markdown]
# # ICP-MS trace metal data in growth media

# %%
icpms_data <- read.csv("Ecoli_icpms.csv", header=T, sep=",")

# %%
icpms_data
# Out:
#    condition   code    media treatment   trace aw    date  V      Mn
# 1  blank       blank   blank blank       blank blank NA    0.0000  0.0000
# 2  blank       blank   blank blank       blank blank NA    0.0100  0.0810
# 3  theoretical SL10    SL10  theoretical TE    no    NA    0.0000 27.4690
# 4  rich        TE      M9    none        TE    no    Feb23 1.6895 25.3995
# 5  rich        TE      M9    none        TE    yes   Feb23 1.5755 24.9840
# 6  depleted    M9_HP   M9HP  high-purity none  yes   Jan24 0.0640  1.7120
# 7  depleted    M9_HP   M9HP  high-purity none  yes   Jan24 0.0850  1.9210
# 8  depleted    M9_HP   M9HP  high-purity none  yes   Jan24 0.0100  2.8550
# 9  depleted    M9_HP   M9HP  high-purity none  yes   Jan24 0.2150  2.5650
# 10 depleted    M9PC    M9PC  chelex      none  yes   Mar24 0.0000  0.0000
# 11 depleted    M9PC    M9PC  chelex      none  yes   Mar24 0.0000  0.4420
# 12 rich        TE      M9    none        TE    no              NA      NA
# ...

# %%
icpms_subset <- subset(icpms_data, code=="blank" | code=="SL10" | code=="M9_HP" | 
              code=="M9PC" | code=="TE")
icpms_subset <- icpms_subset[,c(-1,-3,-4,-5,-6,-7)]

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
icpms_subset %>%
  pivot_longer(!code, names_to = "metals", values_to = "ppb") -> icpms_metals

# %%
ggplot(icpms_metals, aes(x=forcats::fct_relevel(code, "blank", "SL10", "TE", "M9_HP", "M9PC"), y=ppb)) +
        geom_boxplot(aes(fill=metals), color="black") + 

        geom_hline(yintercept = 0) +    

        facet_grid("metals",scales = "free") +

        #       scale_fill_manual(values=c('#045a8d','#b30000')) +

   labs(x = "Trace metal",
       y = "ppb") +

  theme_minimal(base_size = 18) +
theme(axis.ticks.x=element_blank(), 
      axis.ticks.y=element_blank(),
      axis.line = element_line(linewidth = 0.5),
      panel.grid.major.y = element_blank(), panel.grid.minor = element_blank(),
            legend.position="none"
     ) 

ggsave("Fig-S2_icpms.svg", width=12, height=16)
ggsave("Fig-S2_icpms.png", width=12, height=16)
# Out:
# Warning message:
# “Removed 38 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# Warning message:
# “Removed 38 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# Warning message:
# “Removed 38 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
save.image()
